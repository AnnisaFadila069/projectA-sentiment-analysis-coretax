# %% [markdown]
# # **Scraping Coretax News Content**
#
# Web scraping di sini menggunakan `BeautifulSoup` karena library ini memudahkan parsing dan navigasi HTML, serta ekstraksi data seperti teks dan judul artikel. `BeautifulSoup` digunakan bersama `requests` untuk mengambil konten web.

# %% [markdown]
# ## 🔧 Libraries Used

# %%
# Import Library
import pandas as pd
import requests
from bs4 import BeautifulSoup
import re
import time
from datetime import datetime

# %% [markdown]
# ## 📥 Import Data

# %%
# Import data
file_path = "../data/Kelompok 2 Link Article Coretax.xlsx"
ctx_df = pd.read_excel(file_path)
ctx_df
# Out:
#       NO      SUMBER       PENERBIT  \
# 0      1  local news  Suara Merdeka
# 1      2    economic          Detik
# 2      3    economic          Detik
# 3      4  local news       Kumparan
# 4      5  local news           DDTC
# ..   ...         ...            ...
# 156  157    economic          Tempo
# 157  158    economic            MSN
# 158  159    economic       Oke Zone
# 159  160    economic         Bisnis
# 160  161  local news       Kumparan
#
#                                                   LINK  \
# 0    https://diorama.suaramerdeka.com/tech/18315058...
# 1    https://finance.detik.com/berita-ekonomi-bisni...
# 2    https://finance.detik.com/berita-ekonomi-bisni...
# 3    https://kumparan.com/kumparanbisnis/dirjen-paj...
# 4    https://news.ddtc.co.id/berita/nasional/181042...
# ..                                                 ...
# 156  https://www.tempo.co/ekonomi/luhut-sebut-siste...
# 157  https://www.msn.com/id-id/ekonomi/ekonomi/core...
# 158  https://economy.okezone.com/read/2025/04/24/32...
# 159  https://ekonomi.bisnis.com/read/20250423/259/1...
# 160  https://kumparan.com/arisaja200599/dampak-gaga...
#
#                                                  JUDUL
# 0    Coretax Error Hari Ini, 30 April 2025 Cara Per...
# 1    Dirjen Pajak Ungkap Kabar Terbaru soal Perbaik...
# 2    DJP Klaim Aplikasi Coretax Mulai Stabil Digunakan
# 3    Dirjen Pajak Klaim Perbaikan Sistem Coretax Su...
# 4    Latensi Turun, DJP Klaim Coretax System Sudah ...
# ..                                                 ...
# 156  Luhut Sebut Sistem Coretax akan Membaik, Apa i...
# 157  Coretax Kacau, tapi Kenapa Tak Dibahas dalam A...
# 158  Sri Mulyani Pamer Setoran Pajak Naik Jadi Rp13...
# 159   Ditjen Pajak Klaim Performa Coretax Sudah Stabil
# 160  Dampak Gagal Fungsi Coretax terhadap Pemerinta...
#
# [161 rows x 5 columns]

# %% [markdown]
# Output yang ditampilkan adalah dataset yang berisi artikel-artikel mengenai **CoreTax** dari berbagai sumber berita. Terdapat 5 kolom pada dataset, yaitu:
# 1. **NO**: Nomor urut artikel.
# 2. **SUMBER**: Kategori sumber berita
# 3. **PENERBIT**: Nama penerbit atau organisasi yang mempublikasikan artikel.
# 4. **LINK**: URL untuk mengakses artikel tersebut.
# 5. **JUDUL**: Judul artikel yang membahas mengenai CoreTax.
#
# Dataset ini berisi 150 baris data yang terdiri dari berbagai artikel mengenai **CoreTax**.

# %% [markdown]
# # Web Scraping

# %%
# Fungsi untuk menghapus teks iklan, "baca juga", dll.
def clean_content(content):
    # Hapus semua teks yang mengandung "baca juga", "iklan", atau yang sejenis
    content = re.sub(r'\b(Baca Juga|Iklan|ADVERTISEMENT|baca juga|IKLAN)\b', '', content, flags=re.IGNORECASE)
    return ' '.join(content.split())  # Hapus spasi berlebih, jadi satu baris

# %%
def get_article_content(link, retries=3):
    try:
        headers = {
            'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/58.0.3029.110 Safari/537.36'
        }
        response = requests.get(link, headers=headers, timeout=30)

        if response.status_code != 200:
            return None, None, None, "failed"

        soup = BeautifulSoup(response.content, 'html.parser')
        paragraphs = soup.find_all('p')
        content = ' '.join([p.get_text() for p in paragraphs]).strip()

        # Ambil tag
        meta_tags = soup.find('meta', attrs={'name': 'keywords'})
        tags = meta_tags['content'] if meta_tags and 'content' in meta_tags.attrs else "Tidak ada tags"

        # === Ambil tanggal ===
        date = None

        # Coba beberapa cara
        time_tag = soup.find('time')
        if time_tag and time_tag.get('datetime'):
            date = time_tag['datetime']
        elif time_tag:
            date = time_tag.get_text()
        else:
            # Coba cari berdasarkan class umum
            date_tag = soup.find(['span', 'p', 'div'], class_=['date', 'published', 'meta-date', 'entry-date'])
            if date_tag:
                date = date_tag.get_text().strip()

        if len(content) == 0:
            return None, None, None, "failed"

        return content, tags, date, "success"

    except requests.exceptions.RequestException as e:
        if retries > 0:
            print(f"Retrying due to error: {e}. {retries} attempts left.")
            time.sleep(2)
            return get_article_content(link, retries-1)
        return None, None, None, f"failed after retries: {e}"

    except Exception as e:
        print(f"Error lainnya pada {link}: {e}")
        return None, None, None, "failed"

# %%
# Menambah kolom baru untuk konten, tags, date, dan status
ctx_df['content'] = None
ctx_df['tags'] = None
ctx_df['date'] = None
ctx_df['status'] = None

# %%
# Loop untuk mengambil isi berita dari setiap link
success_count = 0
failed_count = 0

for index, row in ctx_df.iterrows():
    link = row['LINK']

    try:
        # Ambil semua 4 nilai dari fungsi get_article_content
        content, tags, date, status = get_article_content(link)

        # Menyimpan hasil dalam DataFrame
        ctx_df.at[index, 'content'] = content if content else "Tidak ada konten"
        ctx_df.at[index, 'tags'] = tags if tags else "Tidak ada tags"
        ctx_df.at[index, 'date'] = date if date else "Tidak ada tanggal"
        ctx_df.at[index, 'status'] = status

        # Menghitung keberhasilan dan kegagalan
        if status == "success":
            success_count += 1
        else:
            failed_count += 1

    except requests.exceptions.RequestException as e:
        print(f"Error mengambil konten dari {link}: {e}")
        ctx_df.at[index, 'content'] = "Error mengambil konten"
        ctx_df.at[index, 'tags'] = "Error mengambil tags"
        ctx_df.at[index, 'date'] = "Error tanggal"
        ctx_df.at[index, 'status'] = "failed"
        failed_count += 1

    except Exception as e:
        print(f"Error lainnya pada {link}: {e}")
        ctx_df.at[index, 'content'] = "Error lainnya"
        ctx_df.at[index, 'tags'] = "Error lainnya"
        ctx_df.at[index, 'date'] = "Error tanggal"
        ctx_df.at[index, 'status'] = "failed"
        failed_count += 1

print(f"Jumlah artikel yang berhasil diambil: {success_count}")
print(f"Jumlah artikel yang gagal diambil: {failed_count}")
# Out:
# Jumlah artikel yang berhasil diambil: 153
# Jumlah artikel yang gagal diambil: 8

# %% [markdown]
# ## 📌 Save Data

# %%
# Simpan DataFrame
output_path = "../data/hasil_scrap_berita.xlsx"
ctx_df.to_excel(output_path, index=False)

# %%
ctx_df
# Out:
#       NO      SUMBER       PENERBIT  \
# 0      1  local news  Suara Merdeka
# 1      2    economic          Detik
# 2      3    economic          Detik
# 3      4  local news       Kumparan
# 4      5  local news           DDTC
# ..   ...         ...            ...
# 156  157    economic          Tempo
# 157  158    economic            MSN
# 158  159    economic       Oke Zone
# 159  160    economic         Bisnis
# 160  161  local news       Kumparan
#
#                                                   LINK  \
# 0    https://diorama.suaramerdeka.com/tech/18315058...
# 1    https://finance.detik.com/berita-ekonomi-bisni...
# 2    https://finance.detik.com/berita-ekonomi-bisni...
# 3    https://kumparan.com/kumparanbisnis/dirjen-paj...
# 4    https://news.ddtc.co.id/berita/nasional/181042...
# ..                                                 ...
# 156  https://www.tempo.co/ekonomi/luhut-sebut-siste...
# 157  https://www.msn.com/id-id/ekonomi/ekonomi/core...
# 158  https://economy.okezone.com/read/2025/04/24/32...
# 159  https://ekonomi.bisnis.com/read/20250423/259/1...
# 160  https://kumparan.com/arisaja200599/dampak-gaga...
#
#                                                  JUDUL  \
# 0    Coretax Error Hari Ini, 30 April 2025 Cara Per...
# 1    Dirjen Pajak Ungkap Kabar Terbaru soal Perbaik...
# 2    DJP Klaim Aplikasi Coretax Mulai Stabil Digunakan
# 3    Dirjen Pajak Klaim Perbaikan Sistem Coretax Su...
# 4    Latensi Turun, DJP Klaim Coretax System Sudah ...
# ..                                                 ...
# 156  Luhut Sebut Sistem Coretax akan Membaik, Apa i...
# 157  Coretax Kacau, tapi Kenapa Tak Dibahas dalam A...
# 158  Sri Mulyani Pamer Setoran Pajak Naik Jadi Rp13...
# 159   Ditjen Pajak Klaim Performa Coretax Sudah Stabil
# 160  Dampak Gagal Fungsi Coretax terhadap Pemerinta...
#
#                                                content  \
# 0                                     Tidak ada konten
# 1    Direktur Jenderal (Dirjen) Pajak Suryo Utomo m...
# 2    Direktorat Jenderal Pajak (DJP) Kementerian Ke...
# 3                                     Tidak ada konten
# 4    Ilustrasi. JAKARTA, DDTCNews - Ditjen Pajak (D...
# ..                                                 ...
# 156  Scroll ke bawah untuk membaca berita   Baca be...
# 157                                   Tidak ada konten
# 158  JAKARTA - Menteri Keuangan Sri Mulyani Indrawa...
# 159  Nyaman tanpa iklan. Langganan BisnisPro Nyaman...
# 160                                   Tidak ada konten
#
#                                                   tags               date  \
# 0                                       Tidak ada tags  Tidak ada tanggal
# 1    coretax,dirjen pajak,administrasi perpajakan,f...  Tidak ada tanggal
# 2    coretax,djp,aplikasi perpajakan,pembaruan,ppnb...  Tidak ada tanggal
# 3                                       Tidak ada tags  Tidak ada tanggal
# 4    administrasi pajak, coretax, coretax system, DJP   Tidak ada tanggal
# ..                                                 ...                ...
# 156                                     Tidak ada tags  Tidak ada tanggal
# 157                                     Tidak ada tags  Tidak ada tanggal
# 158                                     Tidak ada tags  Tidak ada tanggal
# 159  ditjen pajak, coretax, sistem pajak, sistem co...  Tidak ada tanggal
# 160                                     Tidak ada tags  Tidak ada tanggal
#
#       status
# 0     failed
# 1    success
# 2    success
# 3     failed
# 4    success
# ..       ...
# 156  success
# 157   failed
# 158  success
# 159  success
# 160   failed
#
# [161 rows x 9 columns]

# %%
# Menghapus baris yang memiliki status "failed"
ctx_df_cleaned = ctx_df[ctx_df['status'] != 'failed']

# %%
ctx_df_cleaned
# Out:
#          SUMBER      PENERBIT  \
# 0    local news         Tempo
# 1      academic           UGM
# 2    local news  Hukum Online
# 4      academic       Untirta
# 8    local news  Hukum Online
# ..          ...           ...
# 143     opinion     Arah Kata
# 144  local news          CNBC
# 145     opinion       NTVNews
# 147    academic           UGM
# 148  local news          ssas
#
#                                                   LINK  \
# 0    https://www.tempo.co/ekonomi/penerimaan-pajak-...
# 1    https://ugm.ac.id/id/berita/coretax-masih-berm...
# 2    https://www.hukumonline.com/berita/a/problemat...
# 4    https://untirta.ac.id/2025/02/27/optimalisasi-...
# 8    https://www.hukumonline.com/berita/a/gangguan-...
# ..                                                 ...
# 143  https://arahkata.pikiran-rakyat.com/hukrim/pr-...
# 144  https://www.cnbcindonesia.com/news/20250204160...
# 145  https://www.ntvnews.id/ekonomi/0134120/pembuat...
# 147  https://ugm.ac.id/en/news/coretax-faces-challe...
# 148  https://www.ssas.co.id/coretax-megaproyek-paja...
#
#                                                  JUDUL  \
# 0    Penerimaan Pajak Merosot, APINDO: Hingga Kini ...
# 1    Acap Dikeluhkan Wajib Pajak, Pengamat Ini Ungk...
# 2    Problematika CoreTax: Sistem Baru Pelaporan Pa...
# 4    Optimalisasi CoreTax di Lingkungan Akademik: L...
# 8    Gangguan pada Sistem AHU dan Masalah CoreTax H...
# ..                                                 ...
# 143  Dugaan Korupsi Aplikasi CoreTax Rp13 Triliun K...
# 144  Heboh Sistem CoreTax Jebol, Ditjen Pajak Buka ...
# 145  Pembuatan Aplikasi CoreTax Senilai Rp 13 Trili...
# 147  CoreTax Faces Challenges, UGM Economist Highli...
# 148  CoreTax, Megaproyek Pajak yang Masih Tuai Kelu...
#
#                                                content  \
# 0    Baca berita dengan sedikit , klik di sini Baca...
# 1    Direktorat Jenderal Pajak (DJP) Kementerian Ke...
# 2    Platform belajar hukum terbaik secara online d...
# 4    SERANG-Acara Optimalisasi Coretax di lingkunga...
# 8    Platform belajar hukum terbaik secara online d...
# ..                                                 ...
# 143  ARAHKATA - Baru-baru ini, akses menuju sistem ...
# 144  Jakarta, CNBC Indonesia - Pengguna Threads den...
# 145  Ntvnews.id, Jakarta - Pembuatan aplikasi siste...
# 147  In early January, the Directorate General of T...
# 148  Coretax, Megaproyek Pajak yang Masih Tuai Kelu...
#
#                                                   tags   status
# 0                                       Tidak ada tags  success
# 1                                       Tidak ada tags  success
# 2            ditjen-pajak,perpajakan,pajak,wajib-pajak  success
# 4                                       Tidak ada tags  success
# 8    ahu,ahu-online,notaris,administrasi,fidusia,di...  success
# ..                                                 ...      ...
# 143  KPK, korupsi, hukum, dugaan, Kemenkeu, dilapor...  success
# 144                               pajak, coretax, npwp  success
# 145             Coretax DJP,Coretax,pajak,kemenkeu,kpk  success
# 147                                     Tidak ada tags  success
# 148                                     Tidak ada tags  success
#
# [99 rows x 7 columns]

# %%
# Simpan DataFrame yang sudah dibersihkan ke dalam CSV dan Excel
output_csv = 'coretax_content_cleaned.csv'
output_excel = 'coretax_content_cleaned.xlsx'

ctx_df_cleaned.to_csv(output_csv, index=False)
ctx_df_cleaned.to_excel(output_excel, index=False)
