# %% [markdown]
# # 🔄 Preprocessing Data: Cleaning & Preparation 🛠️
# Setelah berhasil melakukan **scraping** data dari berita, langkah selanjutnya adalah **preprocessing**.
# Tahap ini bertujuan untuk membersihkan dan menyiapkan data agar siap untuk analisis lebih lanjut.
#
# ---

# %% [markdown]
# ## 🔧 **Libraries Used**

# %%
import pandas as pd
import re
from Sastrawi.StopWordRemover.StopWordRemoverFactory import StopWordRemoverFactory
from Sastrawi.Stemmer.StemmerFactory import StemmerFactory
from collections import Counter

# %% [markdown]
# ## 📥 **Import Data CSV**

# %%
# Import data
file_path = "../data/hasil_scrap_berita.xlsx"
df = pd.read_excel(file_path)
df
# Out:
#       NO      SUMBER  PENERBIT  \
# 0      2    economic     Detik
# 1      3    economic     Detik
# 2      5  local news      DDTC
# 3      6    economic     Detik
# 4      7  local news     Tempo
# ..   ...         ...       ...
# 149  155  local news      CNBC
# 150  156  local news      Viva
# 151  157    economic     Tempo
# 152  159    economic  Oke Zone
# 153  160    economic    Bisnis
#
#                                                   LINK  \
# 0    https://finance.detik.com/berita-ekonomi-bisni...
# 1    https://finance.detik.com/berita-ekonomi-bisni...
# 2    https://news.ddtc.co.id/berita/nasional/181042...
# 3    https://finance.detik.com/berita-ekonomi-bisni...
# 4    https://www.tempo.co/ekonomi/hari-ini-direktor...
# ..                                                 ...
# 149  https://www.cnbcindonesia.com/news/20250114071...
# 150  https://www.viva.co.id/bisnis/1809316-coretax-...
# 151  https://www.tempo.co/ekonomi/luhut-sebut-siste...
# 152  https://economy.okezone.com/read/2025/04/24/32...
# 153  https://ekonomi.bisnis.com/read/20250423/259/1...
#
#                                                  JUDUL  \
# 0    Dirjen Pajak Ungkap Kabar Terbaru soal Perbaik...
# 1    DJP Klaim Aplikasi Coretax Mulai Stabil Digunakan
# 2    Latensi Turun, DJP Klaim Coretax System Sudah ...
# 3    Awas Penipuan Catut Nama Coretax! Begini Modus...
# 4    Hari Ini Direktorat Jenderal Pajak Rapat Tertu...
# ..                                                 ...
# 149  Keluhan Soal Coretax Terus Muncul: Sistem Tak ...
# 150  Coretax Bermasalah di Awal Tahun, Misbakhun Te...
# 151  Luhut Sebut Sistem Coretax akan Membaik, Apa i...
# 152  Sri Mulyani Pamer Setoran Pajak Naik Jadi Rp13...
# 153   Ditjen Pajak Klaim Performa Coretax Sudah Stabil
#
#                                                content  \
# 0    Direktur Jenderal (Dirjen) Pajak Suryo Utomo m...
# 1    Direktorat Jenderal Pajak (DJP) Kementerian Ke...
# 2    Ilustrasi. JAKARTA, DDTCNews - Ditjen Pajak (D...
# 3    Ditjen Pajak (DJP) Kementerian Keuangan (Kemen...
# 4    Scroll ke bawah untuk membaca berita   Baca be...
# ..                                                 ...
# 149  Jakarta, CNBC Indonesia - Kalangan pengusaha d...
# 150  Jakarta, VIVA – Meskipun terjadi defisit pada ...
# 151  Scroll ke bawah untuk membaca berita   Baca be...
# 152  JAKARTA - Menteri Keuangan Sri Mulyani Indrawa...
# 153  Nyaman tanpa iklan. Langganan BisnisPro Nyaman...
#
#                                                   tags               date  \
# 0    coretax,dirjen pajak,administrasi perpajakan,f...  Tidak ada tanggal
# 1    coretax,djp,aplikasi perpajakan,pembaruan,ppnb...      25 Maret 2025
# 2    administrasi pajak, coretax, coretax system, DJP       30 April 2025
# 3    penipuan,coretax,ditjen pajak,catut nama coret...  Tidak ada tanggal
# 4                                       Tidak ada tags     1 Januari 2025
# ..                                                 ...                ...
# 149                                coretax, pajak, djp     1 Januari 2025
# 150            misbakhun, coretax, apbn, golkar, pajak      22 Maret 2025
# 151                                     Tidak ada tags    17 Januari 2025
# 152                                     Tidak ada tags      24 April 2025
# 153  ditjen pajak, coretax, sistem pajak, sistem co...      25 Maret 2025
#
#       status
# 0    success
# 1    success
# 2    success
# 3    success
# 4    success
# ..       ...
# 149  success
# 150  success
# 151  success
# 152  success
# 153  success
#
# [154 rows x 9 columns]

# %%
#Hanya akan menampilkan kolom berikut
df.loc[:,["SUMBER","PENERBIT","JUDUL", "content", "tags", "date"]]
# Out:
#          SUMBER  PENERBIT                                              JUDUL  \
# 0      economic     Detik  Dirjen Pajak Ungkap Kabar Terbaru soal Perbaik...
# 1      economic     Detik  DJP Klaim Aplikasi Coretax Mulai Stabil Digunakan
# 2    local news      DDTC  Latensi Turun, DJP Klaim Coretax System Sudah ...
# 3      economic     Detik  Awas Penipuan Catut Nama Coretax! Begini Modus...
# 4    local news     Tempo  Hari Ini Direktorat Jenderal Pajak Rapat Tertu...
# ..          ...       ...                                                ...
# 149  local news      CNBC  Keluhan Soal Coretax Terus Muncul: Sistem Tak ...
# 150  local news      Viva  Coretax Bermasalah di Awal Tahun, Misbakhun Te...
# 151    economic     Tempo  Luhut Sebut Sistem Coretax akan Membaik, Apa i...
# 152    economic  Oke Zone  Sri Mulyani Pamer Setoran Pajak Naik Jadi Rp13...
# 153    economic    Bisnis   Ditjen Pajak Klaim Performa Coretax Sudah Stabil
#
#                                                content  \
# 0    Direktur Jenderal (Dirjen) Pajak Suryo Utomo m...
# 1    Direktorat Jenderal Pajak (DJP) Kementerian Ke...
# 2    Ilustrasi. JAKARTA, DDTCNews - Ditjen Pajak (D...
# 3    Ditjen Pajak (DJP) Kementerian Keuangan (Kemen...
# 4    Scroll ke bawah untuk membaca berita   Baca be...
# ..                                                 ...
# 149  Jakarta, CNBC Indonesia - Kalangan pengusaha d...
# 150  Jakarta, VIVA – Meskipun terjadi defisit pada ...
# 151  Scroll ke bawah untuk membaca berita   Baca be...
# 152  JAKARTA - Menteri Keuangan Sri Mulyani Indrawa...
# 153  Nyaman tanpa iklan. Langganan BisnisPro Nyaman...
#
#                                                   tags               date
# 0    coretax,dirjen pajak,administrasi perpajakan,f...  Tidak ada tanggal
# 1    coretax,djp,aplikasi perpajakan,pembaruan,ppnb...      25 Maret 2025
# 2    administrasi pajak, coretax, coretax system, DJP       30 April 2025
# 3    penipuan,coretax,ditjen pajak,catut nama coret...  Tidak ada tanggal
# 4                                       Tidak ada tags     1 Januari 2025
# ..                                                 ...                ...
# 149                                coretax, pajak, djp     1 Januari 2025
# 150            misbakhun, coretax, apbn, golkar, pajak      22 Maret 2025
# 151                                     Tidak ada tags    17 Januari 2025
# 152                                     Tidak ada tags      24 April 2025
# 153  ditjen pajak, coretax, sistem pajak, sistem co...      25 Maret 2025
#
# [154 rows x 6 columns]

# %% [markdown]
# ## 📊 **Cek Sentiment Analysis**

# %%
# # Handle None values in 'content' column by replacing them with empty strings
# df['sentiment_polarity'] = df['content'].astype(str).apply(lambda x: TextBlob(x).polarity)
# df['sentiment_subjective'] = df['content'].astype(str).apply(lambda x: TextBlob(x).subjectivity)

# %%
# #Add a column name polarity_rating from changing the score of the review into 3 labels: Pos, Negative Neutral
# df['sentiment_rating'] = df['score'].apply(lambda x: 'Positive' if x > 3 else('Neutral' if x == 3  else 'Negative'))

# %%
# df.loc[:,["content","score","sentiment_polarity", "sentiment_subjective","sentiment_rating"]]

# %%
# plt.figure(figsize=(15, 10))
# # Specify x and y using the 'x' and 'y' parameters within sns.scatterplot
# sns.scatterplot(x=df['sentiment_polarity'], y=df['sentiment_subjective'],
#                 hue=df['sentiment_rating'], edgecolor='white', palette="pastel")
# plt.title("Google Play Store Running App Reviews Sentiment Analysis", fontsize=20)
# plt.show()

# %%
# # Function to plot most frequent terms
# def freq_words(x, terms=30, title="Frekuensi Kata"):
#     all_words = ' '.join([text for text in x])
#     all_words = all_words.split()
    
#     # Hitung frekuensi kata
#     fdist = FreqDist(all_words)
#     words_df = pd.DataFrame({'word': list(fdist.keys()), 'count': list(fdist.values())})

#     # Pilih top-n kata paling sering muncul
#     d = words_df.nlargest(columns="count", n=terms)

#     # Plot dengan seaborn
#     plt.figure(figsize=(20, 5))
#     ax = sns.barplot(data=d, x="word", y="count", hue="word", palette="rainbow", legend=False)
#     ax.set(ylabel='Count')

#     # Tambahkan judul
#     plt.title(title, fontsize=14)
#     plt.xticks(rotation=45)  # Rotasi label agar lebih mudah dibaca
#     plt.show()

# # Panggil fungsi dengan judul yang sesuai
# df['content'] = df['content'].fillna('').astype(str)
# freq_words(df['content'], title="Frekuensi Words Before Preprocessing")

# %% [markdown]
# ## 📌 **Tahapan Preprocessing**

# %% [markdown]
# ### ✅ **1. Handling Missing Values** → Menghapus atau mengisi data yang kosong

# %%
print(df.isnull().sum())
# Out:
# NO          0
# SUMBER      0
# PENERBIT    0
# LINK        0
# JUDUL       0
# content     0
# tags        0
# date        0
# status      0
# dtype: int64

# %% [markdown]
# Data tidak ada yang kosong

# %% [markdown]
# ### ✅ **2. Lowercasing** → Mengubah teks menjadi huruf kecil untuk konsistensi

# %%
# Ubah ke lowercase hanya pada kolom teks
df['JUDUL'] = df['JUDUL'].str.lower()
df['tags'] = df['tags'].str.lower()
df['content'] = df['content'].str.lower()

# %%
df.head()
# Out:
#    NO      SUMBER PENERBIT                                               LINK  \
# 0   2    economic    Detik  https://finance.detik.com/berita-ekonomi-bisni...
# 1   3    economic    Detik  https://finance.detik.com/berita-ekonomi-bisni...
# 2   5  local news     DDTC  https://news.ddtc.co.id/berita/nasional/181042...
# 3   6    economic    Detik  https://finance.detik.com/berita-ekonomi-bisni...
# 4   7  local news    Tempo  https://www.tempo.co/ekonomi/hari-ini-direktor...
#
#                                                JUDUL  \
# 0  dirjen pajak ungkap kabar terbaru soal perbaik...
# 1  djp klaim aplikasi coretax mulai stabil digunakan
# 2  latensi turun, djp klaim coretax system sudah ...
# 3  awas penipuan catut nama coretax! begini modus...
# 4  hari ini direktorat jenderal pajak rapat tertu...
#
#                                              content  \
# 0  direktur jenderal (dirjen) pajak suryo utomo m...
# 1  direktorat jenderal pajak (djp) kementerian ke...
# 2  ilustrasi. jakarta, ddtcnews - ditjen pajak (d...
# 3  ditjen pajak (djp) kementerian keuangan (kemen...
# 4  scroll ke bawah untuk membaca berita   baca be...
#
#                                                 tags               date  \
# 0  coretax,dirjen pajak,administrasi perpajakan,f...  Tidak ada tanggal
# 1  coretax,djp,aplikasi perpajakan,pembaruan,ppnb...      25 Maret 2025
# 2  administrasi pajak, coretax, coretax system, djp       30 April 2025
# 3  penipuan,coretax,ditjen pajak,catut nama coret...  Tidak ada tanggal
# 4                                     tidak ada tags     1 Januari 2025
#
#     status
# 0  success
# 1  success
# 2  success
# 3  success
# 4  success

# %% [markdown]
# ### ✅ **3. Special Characters Removal** → menghapus kata spesial pada berita

# %%
def clean_text(text):
    # text = re.sub(r'^[a-zA-Z\s,]+[-\s–]+', '', text)
    text = re.sub(r'\([^)]*\)', '', text) #menghapus teks dalam kurung
    text = re.sub(r'http[s]?://\S+', '', text) #menghapus url
    text = re.sub(r'^[^—-]+[-—]\s*', '', text) ## Menghapus kata penerbit, kota di awal
    text = re.sub(r'^\d{1,2}\s\w+\s\d{4}\s*[-:]\s*', '', text) #menghapus tanggal
    text = re.sub(r'&\w+;', ' ', text)       # karakter html, Contoh: &nbsp; &quot;
    text = re.sub(r'&#\d+;', ' ', text)      # karalter html, Contoh: &#x27;
    text = re.sub(r'\d+', '', text)          # Menghapus angka
    return text

# Terapkan pada kolom 'content'
df['clean_text'] = df['content'].apply(clean_text)

# %%
df.loc[:,["content", "clean_text"]]
# Out:
#                                                content  \
# 0    direktur jenderal (dirjen) pajak suryo utomo m...
# 1    direktorat jenderal pajak (djp) kementerian ke...
# 2    ilustrasi. jakarta, ddtcnews - ditjen pajak (d...
# 3    ditjen pajak (djp) kementerian keuangan (kemen...
# 4    scroll ke bawah untuk membaca berita   baca be...
# ..                                                 ...
# 149  jakarta, cnbc indonesia - kalangan pengusaha d...
# 150  jakarta, viva – meskipun terjadi defisit pada ...
# 151  scroll ke bawah untuk membaca berita   baca be...
# 152  jakarta - menteri keuangan sri mulyani indrawa...
# 153  nyaman tanpa iklan. langganan bisnispro nyaman...
#
#                                             clean_text
# 0    direktur jenderal  pajak suryo utomo mengungka...
# 1    rata berada di bawah , detik, dengan performa ...
# 2    ditjen pajak  menilai performa coretax adminis...
# 3    akhir ini marak penipuan yang mengatasnamakan ...
# 4    direktur jenderal atau dirjen pajak kementeria...
# ..                                                 ...
# 149  kalangan pengusaha dan pakar pajak memberikan ...
# 150  bulan berikutnya. makanya, misbakhun meminta p...
# 151  masih bermasalah di pekan kedua setelah diimpl...
# 152  menteri keuangan sri mulyani indrawati mengung...
# 153  direktorat jenderal pajak mengklaim performa s...
#
# [154 rows x 2 columns]

# %% [markdown]
# ### ✅ **4. Punctuations removal** → Menghapus tanda baca dan simbol yang tidak relevan.

# %%
def clean_special_chars(text):
    # Hilangkan emoji dan simbol unicode lainnya
    text = re.sub(r'[^\x00-\x7F]+', ' ', text)  
    
    # Hilangkan tanda baca dan simbol matematika
    text = re.sub(r'[^\w\s]', ' ', text)

    # Hilangkan extra whitespace
    text = re.sub(r'\s+', ' ', text).strip()
    
    return text

# Terapkan
df['content_clean'] = df['clean_text'].apply(clean_special_chars)

# %%
df.loc[:,["clean_text", "content_clean"]]
# Out:
#                                             clean_text  \
# 0    direktur jenderal  pajak suryo utomo mengungka...
# 1    rata berada di bawah , detik, dengan performa ...
# 2    ditjen pajak  menilai performa coretax adminis...
# 3    akhir ini marak penipuan yang mengatasnamakan ...
# 4    direktur jenderal atau dirjen pajak kementeria...
# ..                                                 ...
# 149  kalangan pengusaha dan pakar pajak memberikan ...
# 150  bulan berikutnya. makanya, misbakhun meminta p...
# 151  masih bermasalah di pekan kedua setelah diimpl...
# 152  menteri keuangan sri mulyani indrawati mengung...
# 153  direktorat jenderal pajak mengklaim performa s...
#
#                                          content_clean
# 0    direktur jenderal pajak suryo utomo mengungkap...
# 1    rata berada di bawah detik dengan performa ter...
# 2    ditjen pajak menilai performa coretax administ...
# 3    akhir ini marak penipuan yang mengatasnamakan ...
# 4    direktur jenderal atau dirjen pajak kementeria...
# ..                                                 ...
# 149  kalangan pengusaha dan pakar pajak memberikan ...
# 150  bulan berikutnya makanya misbakhun meminta par...
# 151  masih bermasalah di pekan kedua setelah diimpl...
# 152  menteri keuangan sri mulyani indrawati mengung...
# 153  direktorat jenderal pajak mengklaim performa s...
#
# [154 rows x 2 columns]

# %% [markdown]
# ### ✅ **5. Tokenization** → Memisahkan teks menjadi kata-kata atau unit kecil lainnya.

# %%
def tokenize(text):
    return re.findall(r'\b\w+\b', text.lower())

# Apply
df['tokens'] = df['content_clean'].apply(tokenize)

# %%
# Cek hasil tokenisasi
df[["content_clean", "tokens"]].head()
# Out:
#                                        content_clean  \
# 0  direktur jenderal pajak suryo utomo mengungkap...
# 1  rata berada di bawah detik dengan performa ter...
# 2  ditjen pajak menilai performa coretax administ...
# 3  akhir ini marak penipuan yang mengatasnamakan ...
# 4  direktur jenderal atau dirjen pajak kementeria...
#
#                                               tokens
# 0  [direktur, jenderal, pajak, suryo, utomo, meng...
# 1  [rata, berada, di, bawah, detik, dengan, perfo...
# 2  [ditjen, pajak, menilai, performa, coretax, ad...
# 3  [akhir, ini, marak, penipuan, yang, mengatasna...
# 4  [direktur, jenderal, atau, dirjen, pajak, keme...

# %% [markdown]
# ### ✅ **6. Stopword Removal** → Menghapus kata-kata umum yang tidak bermakna dalam analisis

# %%
stop_factory = StopWordRemoverFactory()
stop_words = set(stop_factory.get_stop_words())

filtered_stop_words = stop_words.copy()
new_stopwords = ["ada", "lalu", "guna", "klik", "sini", "beri", "bagai", "atas", "bulan", "sama", "kini"] # Bisa menambahkan stopword lain sesuai kebutuhan

def remove_stopwords(tokens):
    cleaned_tokens = [
        token.strip() for token in tokens  # Hapus spasi atau karakter aneh
        if len(token) > 3  # Hapus kata tidak penting
    ]
    # Menghapus stopwords dari token
    return [t for t in cleaned_tokens if t.lower() not in filtered_stop_words]

# Terapkan ke DataFrame
df['stopword_removal'] = df['tokens'].apply(remove_stopwords)

# %%
# Cek hasil 
df[["tokens", "stopword_removal"]].head()
# Out:
#                                               tokens  \
# 0  [direktur, jenderal, pajak, suryo, utomo, meng...
# 1  [rata, berada, di, bawah, detik, dengan, perfo...
# 2  [ditjen, pajak, menilai, performa, coretax, ad...
# 3  [akhir, ini, marak, penipuan, yang, mengatasna...
# 4  [direktur, jenderal, atau, dirjen, pajak, keme...
#
#                                     stopword_removal
# 0  [direktur, jenderal, pajak, suryo, utomo, meng...
# 1  [rata, berada, bawah, detik, performa, terbaik...
# 2  [ditjen, pajak, menilai, performa, coretax, ad...
# 3  [akhir, marak, penipuan, mengatasnamakan, impl...
# 4  [direktur, jenderal, dirjen, pajak, kementeria...

# %% [markdown]
# ### ✅ **7.  Stemming** → Mengubah kata menjadi bentuk dasarnya

# %%
# Membuat objek stemmer
stem_factory = StemmerFactory()
stemmer = stem_factory.create_stemmer()

# Fungsi untuk melakukan stemming pada tokens
def stem_tokens(tokens):
    return [stemmer.stem(token) for token in tokens]

# Terapkan stemming ke DataFrame
df['stemming_output'] = df['stopword_removal'].apply(stem_tokens)

# %%
# Cek hasil 
df[["stopword_removal", "stemming_output"]].head()
# Out:
#                                     stopword_removal  \
# 0  [direktur, jenderal, pajak, suryo, utomo, meng...
# 1  [rata, berada, bawah, detik, performa, terbaik...
# 2  [ditjen, pajak, menilai, performa, coretax, ad...
# 3  [akhir, marak, penipuan, mengatasnamakan, impl...
# 4  [direktur, jenderal, dirjen, pajak, kementeria...
#
#                                      stemming_output
# 0  [direktur, jenderal, pajak, suryo, utomo, ungk...
# 1  [rata, ada, bawah, detik, performa, baik, cata...
# 2  [ditjen, pajak, nilai, performa, coretax, admi...
# 3  [akhir, marak, tipu, mengatasnamakan, implemen...
# 4  [direktur, jenderal, dirjen, pajak, menteri, u...

# %% [markdown]
# ### ✅ **8. Rare Words Removal** → Menghapus kata yang jarang muncul.

# %%
word_counts = Counter(word for tokens in df["stemming_output"] for word in tokens)

rare_threshold = 2
rare_words = {word for word, count in word_counts.items() if count < rare_threshold}

def remove_rare_words(tokens):
    return [word for word in tokens if word not in rare_words]

df['rareword_removed'] = df['stemming_output'].apply(remove_rare_words)

# %%
# Cek hasil 
df[["stemming_output", "rareword_removed",]].head()
# Out:
#                                      stemming_output  \
# 0  [direktur, jenderal, pajak, suryo, utomo, ungk...
# 1  [rata, ada, bawah, detik, performa, baik, cata...
# 2  [ditjen, pajak, nilai, performa, coretax, admi...
# 3  [akhir, marak, tipu, mengatasnamakan, implemen...
# 4  [direktur, jenderal, dirjen, pajak, menteri, u...
#
#                                     rareword_removed
# 0  [direktur, jenderal, pajak, suryo, utomo, ungk...
# 1  [rata, ada, bawah, detik, performa, baik, cata...
# 2  [ditjen, pajak, nilai, performa, coretax, admi...
# 3  [akhir, marak, tipu, mengatasnamakan, implemen...
# 4  [direktur, jenderal, dirjen, pajak, menteri, u...

# %%
from collections import Counter

# Gabungkan semua token dalam kolom 'rareword_removed' menjadi satu list
all_words = [word for tokens in df['rareword_removed'] for word in tokens]

# Hitung frekuensi kemunculan setiap kata
word_counts = Counter(all_words)

# Tampilkan hasil
print(word_counts)
# Out:
# Counter({'pajak': 2204, 'coretax': 1247, 'sistem': 901, 'wajib': 678, 'faktur': 554, 'paja': 502, 'jadi': 480, 'laku': 422, 'data': 419, 'terima': 392, 'sebut': 346, 'lalu': 326, 'guna': 318, 'baik': 300, 'layan': 295, 'baca': 295, 'tahun': 279, 'lebih': 276, 'lapor': 271, 'proses': 266, 'masalah': 256, 'buat': 256, 'administrasi': 253, 'kata': 250, 'berita': 241, 'iklan': 234, 'januari': 229, 'tingkat': 228, 'negara': 228, 'besar': 227, 'masa': 224, 'usaha': 221, 'indonesia': 221, 'baru': 218, 'kendala': 208, 'klik': 207, 'sini': 204, 'uang': 203, 'banyak': 200, 'sedikit': 195, 'implementasi': 192, 'hasil': 191, 'perintah': 189, 'menteri': 183, 'hingga': 181, 'lama': 179, 'dapat': 174, 'terap': 162, 'beri': 162, 'aplikasi': 161, 'akses': 161, 'masuk': 161, 'perlu': 161, 'satu': 156, 'jenderal': 154, 'atas': 154, 'bagai': 154, 'triliun': 146, 'system': 144, 'kait': 142, 'hukum': 141, 'jumlah': 140, 'direktorat': 139, 'maret': 134, 'tambah': 134, 'bulan': 132, 'bayar': 131, 'kena': 129, 'jalan': 129, 'beberapa': 124, 'integrasi': 123, 'awal': 122, 'ekonomi': 122, 'februari': 121, 'informasi': 121, 'terbit': 119, 'langkah': 118, 'utama': 115, 'potong': 115, 'bukti': 114, 'nilai': 114, 'risiko': 114, 'salah': 113, 'terus': 111, 'ganggu': 111, 'daftar': 109, 'turun': 109, 'ada': 108, 'waktu': 106, 'sampai': 106, 'alami': 105, 'sebab': 105, 'akibat': 105, 'mudah': 104, 'jelas': 103, 'media': 102, 'pasti': 102, 'masyarakat': 102, 'digital': 101, 'pihak': 100, 'kurang': 98, 'atur': 98, 'akhir': 97, 'kantor': 95, 'sejak': 94, 'capai': 94, 'umum': 94, 'benar': 94, 'tuju': 93, 'akun': 93, 'penting': 93, 'nomor': 92, 'mulyani': 90, 'teknologi': 89, 'milik': 89, 'mulai': 88, 'ubah': 88, 'hari': 88, 'program': 88, 'seluruh': 88, 'belum': 87, 'kembang': 87, 'sama': 87, 'ujar': 85, 'keluh': 85, 'hubung': 84, 'tetap': 84, 'harap': 84, 'kerja': 83, 'anggar': 83, 'rupa': 82, 'khusus': 82, 'industri': 81, 'aman': 81, 'pasal': 80, 'resmi': 80, 'tulis': 80, 'bisnis': 79, 'kini': 78, 'kelola': 77, 'siap': 77, 'npwp': 77, 'minta': 76, 'detik': 75, 'target': 75, 'orang': 75, 'teknis': 75, 'sesuai': 74, 'luncur': 74, 'tentu': 74, 'transaksi': 74, 'proyek': 73, 'juta': 72, 'ikut': 72, 'komisi': 72, 'lanjut': 71, 'dasar': 71, 'direktur': 70, 'surat': 70, 'dokumen': 70, 'soal': 70, 'patuh': 70, 'sertifikat': 70, 'unggah': 69, 'muncul': 69, 'jakarta': 68, 'sanksi': 68, 'lihat': 68, 'ungkap': 67, 'april': 67, 'temu': 66, 'lambat': 66, 'persen': 66, 'laksana': 66, 'nyata': 65, 'bangun': 65, 'sulit': 64, 'kemudian': 64, 'upaya': 64, 'tengah': 64, 'periksa': 64, 'undang': 64, 'cepat': 63, 'bijak': 62, 'tempo': 62, 'butuh': 62, 'dampak': 61, 'turut': 60, 'tiga': 60, 'solusi': 60, 'transisi': 60, 'tarif': 59, 'lengkap': 59, 'bagi': 59, 'meski': 58, 'impor': 58, 'bas': 58, 'putus': 57, 'inti': 57, 'dukung': 57, 'sedia': 57, 'latensi': 56, 'miliar': 56, 'batas': 56, 'duga': 56, 'banding': 55, 'siber': 55, 'nyaman': 55, 'prabowo': 54, 'reformasi': 54, 'semua': 54, 'sangat': 53, 'terang': 53, 'ketua': 53, 'tunjuk': 52, 'kode': 52, 'platform': 52, 'selesai': 51, 'hambat': 51, 'ditjen': 51, 'login': 51, 'total': 51, 'fitur': 51, 'catat': 50, 'sempurna': 50, 'format': 50, 'langsung': 50, 'jawab': 50, 'instagram': 49, 'tekan': 49, 'dua': 49, 'status': 49, 'segera': 48, 'mungkin': 48, 'tegas': 48, 'potensi': 48, 'korupsi': 48, 'suryo': 47, 'diri': 47, 'pilih': 47, 'skema': 47, 'kuat': 47, 'pukul': 46, 'hapus': 46, 'langgan': 46, 'bukan': 45, 'presiden': 45, 'bahkan': 45, 'pusat': 45, 'tahap': 45, 'nama': 45, 'kirim': 45, 'core': 45, 'elektronik': 45, 'ucap': 45, 'bisnispro': 45, 'dirjen': 44, 'email': 44, 'optimal': 44, 'online': 44, 'bank': 44, 'maupun': 44, 'badan': 44, 'artikel': 44, 'makin': 43, 'kalau': 43, 'tanggal': 43, 'dorong': 43, 'anjlok': 43, 'hadap': 43, 'harga': 43, 'kapasitas': 43, 'penuh': 43, 'luhut': 42, 'senin': 42, 'beda': 42, 'kutip': 42, 'pemberitahuan': 41, 'lain': 41, 'awas': 41, 'pertama': 41, 'suluh': 41, 'setor': 41, 'gagal': 41, 'menit': 41,  ...

# %% [markdown]
# ### ✅ **9. Delete Empty Rows**

# %%
# Cek jumlah baris yang memiliki token kosong setelah preprocessing
df_empty = df[df["rareword_removed"].apply(lambda x: len(x) == 0)]
print(f"Jumlah baris kosong: {len(df_empty)}")
# Out:
# Jumlah baris kosong: 0

# %% [markdown]
# ## 📌 **Save Data**

# %%
# Simpan DataFrame
output_path = "../data/hasil_preprocessing.xlsx"
df.to_excel(output_path, index=False)
